# %% [markdown]
# # NLP Assignment 6
#
# Harsh Kashyap
# 101917088
# CSE4

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

df = pd.read_pickle('pickle\corpus.pkl')
df
# Out:
#                                                        Transcript  \
# Amer_Mohammed   [quirky flute music playing]\r\n [single note ...
# Dave_2          June 6, 2020\r\n 8:46 is a performance special...
# Dave_Chappelle  [audience murmuring]\r\n [murmuring continues]...
# Drew_Michael_1  “This is the latest I’ve stayed up in a long t...
# Drew_Michael_2  (EMOTIONAL MUSIC PLAYING)\r\n (MUSIC ENDS)\r\n...
# Jim_Gaffigan    Thank you! Thank you! Oh, my gosh. Thank you s...
# Kathleen        [chattering]\r\n [man] Whoo!\r\n [chattering]\...
# Lousi           Recorded at the Madison Square Garden on Augus...
# Phil            [hip-hop music playing]\r\n [audience cheering...
# Tom             aired December 2016\r\n [plodding music]\r\n ♪...
#
#                        Full Name
# Amer_Mohammed      Amer Mohammed
# Dave_2            Dave Chappelle
# Dave_Chappelle          Ch. Dave
# Drew_Michael_1      Drew Michael
# Drew_Michael_2           M. Drew
# Jim_Gaffigan        Jim Gaffigan
# ...

# %%
# Extract only Ali Wong's text
Tom_text = df['Transcript'].loc['Tom']
Tom_text[:200]
# Out:
# 'aired December 2016\r\n [plodding music]\r\n ♪\r\n Please welcome to the stage Tom Papa.\r\n [cheers and applause]\r\n Thank you.\r\n [cheers and applause continue]\r\n Cleveland. Thank you so much. You guys look g'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Tom's routine, take a look at it
tom_dict = markov_chain(Tom_text)
tom_dict
# Out:
# {'aired': ['December'],
#  'December': ['2016\r\n'],
#  '2016\r\n': ['[plodding'],
#  '[plodding': ['music]\r\n'],
#  'music]\r\n': ['♪\r\n'],
#  '♪\r\n': ['Please'],
#  'Please': ['welcome'],
#  'welcome': ['to'],
#  'to': ['the',
#   'see',
#   'cancel.',
#   'the',
#   'go?”',
#   'be',
#   'do',
#   '“I’m',
#   'listen',
#   'him',
#   'call',
#   'go',
#   'school,',
#   'cancel,',
#   'a',
#   'you.',
#   'fight',
#   'use',
#   'think',
#   'scam',
#   'have',
#   'me.',
#   'me,',
#   'get',
#   'scare',
#   'the',
#   'the',
#   'the',
#   'have',
#   'your',
#   'your',
#   'get',
#   'eat',
#   'wait',
#   'lay',
#   'get',
#   'drink,',
#   'hear.',
#   'have',
#   'enjoy',
#   'enjoy',
#   'affect',
#   'accomplish?',
#   'the',
#   'ask',
#   'Keith’s',
#   'Keith’s',
#   'ten',
#   'them.',
#   'these',
#   'be',
#   'school.',
#   'practice',
#   'the',
#   'quit',
#   'the',
#   'jokes.\r\n',
#   'go',
#   'my',
#   'be',
#   'make',
#   'make',
#   'be',
#   'get',
# ...

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(tom_dict)
# Out:
# 'Billionaire to spend it. I’m not wrong. I couldn’t imagine, as great as therapy.\r\n ©.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
amer_text  = df['Transcript'].loc['Amer_Mohammed']
amer_dict = markov_chain(amer_text)
generate_sentence(amer_dict,20)
# Out:
# 'Amer day of his first HBO stand-up special, but that’s what I’m like they’re like, “You okay, Dave?” He was.'

# %%
dave2_text  = df['Transcript'].loc['Dave_2']
dave2_dict = markov_chain(dave2_text)
generate_sentence(dave2_dict,25)
# Out:
# 'Asymmetrical war on a fuck.\r\n There’s other night, the military, and whooped his wife lived in a still keep this amazing work, well they’re going.'

# %%
drew1_text  = df['Transcript'].loc['Drew_Michael_1']
drew1_dict = markov_chain(drew1_text)
generate_sentence(drew1_dict,30)
# Out:
# 'Ad campaign?\r\n Where’s that that to recognize parts of the latest I’ve built up people that people, you know wha…\r\n You still get why you guess that’s well be my.'

# %%
drew2_text  = df['Transcript'].loc['Drew_Michael_2']
drew2_dict = markov_chain(drew2_text)
generate_sentence(drew2_dict,35)
# Out:
# 'Than hate.” And it’s called psychoanalysis, and Dad’s addicted to an adult. I would get in my friends were no toothpicks, if you didn’t know everything about them. And I used to an eight-year-old boy,.'

# %%
jim_text  = df['Transcript'].loc['Jim_Gaffigan']
jim_dict = markov_chain(jim_text)
generate_sentence(jim_dict,40)
# Out:
# 'Americans would tourists feel so critical of different cats. Always the lockdown was like, “Jim, you’re a fancy event. When I don’t go for both dress like someone you’d think of a pumpkin spice latte.” That vest like I believe.'

# %%
kath_text  = df['Transcript'].loc['Kathleen']
kath_dict = markov_chain(kath_text)
generate_sentence(kath_dict,45)
# Out:
# 'Sister.”\r\n And I let them individually.\r\n ’Cause you were in their palms are buying.\r\n I’m in it.\r\n Google this.\r\n About that puts me the whole family since you’re like, basically an environmental group, and told me back is, “What?”\r\n And I get hot.\r\n You’re allowed.'

# %%
Lousi_text  = df['Transcript'].loc['Lousi']
Lousi_dict = markov_chain(Lousi_text)
generate_sentence(Lousi_dict,50)
# Out:
# 'Shame there. Uh…\r\n [Laughter]\r\n By the face it, so I’ll… I’ll tell me, he’s like, in my bathroom. I’m a full two-pound dump in the way I said, “All right,” you know it.” That’s why.\r\n [Cheering and you understand? Even just hears… [Gibberish] [Gibberish] She was 3,000 people f*cking. I.'

# %%
Phil_text  = df['Transcript'].loc['Phil']
Phil_dict = markov_chain(Phil_text)
generate_sentence(Phil_dict,55)
# Out:
# 'Centipede. Good luck. Good luck. Good luck and his balls! London Palladium, if a dry patch…\r\n and comedy as therapy.\r\n © 2021 Scraps from me. I’m covered in my butt. They’re absolutely love a spring chicken. Oh, my young farts.\r\n [mimics fireworks]\r\n Then threats started working out. Thank you!\r\n I was a centipede. Good luck.'

# %%
import random
import string 

def generate_sentence(chain, count=15):
    
    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
        if word2[-1] in string.punctuation:
            return(sentence)

    # End it with a period
    sentence += random.choice(string.punctuation)
    return(sentence)

# %%
generate_sentence(tom_dict,50)
# Out:
# 'Excited to throw it at Old Navy.'
